# %%
pip install pywhatkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## IMPORTO LIBRERIAS

# %%
#import pywhatkit as pw
import datetime
import pandas as pd
import pyautogui as pg
import time
import webbrowser as web
import pywhatkit 
import os
#import  pyautogui

# %% [markdown]
# ## IMPORTO FILE

# %%
current_path=os.getcwd()
final_path=current_path+'\\ENVIO\\'

# %%
files=os.listdir(final_path)
file=files[0]
file
# Out:
# 'cuotavisitas_TATA_2023-04-11_JOURNEY.csv'

# %%
df=pd.read_csv(final_path+file)

# %%
df.head()
# Out:
#   FECHA_CARGA  SOCI_SOCI_ID CLIE_TIPO_DOC  CLIE_CLIE_NDOC TIPO_DOC_DOC  \
# 0  2023-04-11       1239014             C        56482012    C56482012
# 1  2023-04-11       1245971             C        39482962    C39482962
# 2  2023-04-11       1245893             C        18231796    C18231796
# 3  2023-04-11       1237161             C        36791027    C36791027
# 4  2023-04-11       1235506             C        50198443    C50198443
#
#   ULTIMOS_4     CELULAR CORREO CAMP_COST_CANAL LOCALE  MESES_VINIERON_AJ  \
# 0   CI:2012  92185148.0    NaN             SMS  ES-UY                  2
# 1   CI:2962  93507596.0    NaN             SMS  ES-UY                  3
# 2   CI:1796  98874551.0    NaN             SMS  ES-UY                  3
# 3   CI:1027  92486652.0    NaN             SMS  ES-UY                  2
# 4   CI:8443  93559696.0    NaN             SMS  ES-UY                  3
#
#    VENTAS_PROMEDIO_A  VENTAS_ACTUAL  TICKET_PROMEDIO_A  TICKETS_ACTUAL  \
# ...

# %%
lista_celu=df[df.CORREO.isna()]
lista_celu.reset_index(inplace=True)
lista_celu.drop(columns=['index'] , inplace=True)
lista_celu.head()
# Out:
# C:\Users\julia.scipioni\AppData\Local\Temp\ipykernel_28960\1325301003.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_celu.drop(columns=['index'] , inplace=True)
#   FECHA_CARGA  SOCI_SOCI_ID CLIE_TIPO_DOC  CLIE_CLIE_NDOC TIPO_DOC_DOC  \
# 0  2023-04-11       1239014             C        56482012    C56482012
# 1  2023-04-11       1245971             C        39482962    C39482962
# 2  2023-04-11       1245893             C        18231796    C18231796
# 3  2023-04-11       1237161             C        36791027    C36791027
# 4  2023-04-11       1235506             C        50198443    C50198443
#
#   ULTIMOS_4     CELULAR CORREO CAMP_COST_CANAL LOCALE  MESES_VINIERON_AJ  \
# 0   CI:2012  92185148.0    NaN             SMS  ES-UY                  2
# ...

# %%
lista_celu=lista_celu[['CELULAR','ULTIMOS_4']]
lista_celu.head()
# Out:
#       CELULAR ULTIMOS_4
# 0  92185148.0   CI:2012
# 1  93507596.0   CI:2962
# 2  98874551.0   CI:1796
# 3  92486652.0   CI:1027
# 4  93559696.0   CI:8443

# %% [markdown]
# ## HAGO CORRECCIONES A LOS NUMEROS Y COLUMNAS

# %%
lista_celu.NUMERO_CELULAR=lista_celu.CELULAR.astype(str).str[:-2]
lista_celu.head()
lista_celu['NUMERO_CELULAR']='598'+lista_celu.NUMERO_CELULAR
lista_celu.head()
#a
# Out:
# C:\Users\julia.scipioni\AppData\Local\Temp\ipykernel_28960\3010380159.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   lista_celu.NUMERO_CELULAR=lista_celu.CELULAR.astype(str).str[:-2]
#       CELULAR ULTIMOS_4 NUMERO_CELULAR
# 0  92185148.0   CI:2012    59892185148
# 1  93507596.0   CI:2962    59893507596
# 2  98874551.0   CI:1796    59898874551
# 3  92486652.0   CI:1027    59892486652
# 4  93559696.0   CI:8443    59893559696

# %% [markdown]
# ## ENVIO

# %%
def envio_wpp(df,mensaje):

# %%
lista_celu_prueba=lista_celu[:5]
lista_celu_prueba.NUMERO_CELULAR='+5491141429806'
lista_celu_prueba
# Out:
# C:\Users\julia.scipioni\AppData\Local\Temp\ipykernel_28960\212097424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_celu_prueba.NUMERO_CELULAR='+5491141429806'
#       CELULAR ULTIMOS_4  NUMERO_CELULAR
# 0  92185148.0   CI:2012  +5491141429806
# 1  93507596.0   CI:2962  +5491141429806
# 2  98874551.0   CI:1796  +5491141429806
# 3  92486652.0   CI:1027  +5491141429806
# 4  93559696.0   CI:8443  +5491141429806

# %% [markdown]
# ## ENVIO IMAGENES

# %%
### PARA ENVIAR IMAGENES 🙌

for i in range(0,len(lista_celu_prueba)):
    pywhatkit.sendwhats_image( lista_celu_prueba.NUMERO_CELULAR[i],"imagen\\PLUS-TATA-CUOTA-VISITA_00.jpg", """Porque siempre nos elegís, *PLUS TE REGALA 200 pesos* en tu próxima compra en Ta-Ta. Minimo de compra y mas info: http://5ee.us/kfwqZH? _Valido hasta 30/04_ - """+lista_celu_prueba.ULTIMOS_4[i],10,True,5)

# %%
os.listdir(final_path+'..\\imagen')
# Out:
# ['PLUS-TATA-CUOTA-VISITA_00.jpg']

# %%
# import time,webbrowser, pyautogui
# open_close(url="https://www.python.org/")
# webbrowser.open(url)
# time.sleep(5)
# pyautogui.hotkey('ctrl', 'w')
# print("tab closed")

# %%
# import snowflake.connector
# import json
# from functions import arreglo_caracteristicas
# import datetime

# f = open('claves_correo_snow.json')
# data_pass = json.load(f)

# pass_ = input("ingresar passcode:")

# ctx = snowflake.connector.connect(
#     user= data_pass['snow'][0]['user'],
#     password= data_pass['snow'][0]['pass'],
#     account='dp32414.us-east-1',
#     passcode=pass_,
#     database='sandbox_plus',
#     schema='dwh'
# )

# fecha_final = '2023-03-01'
# fecha_inicio =  '2023-02-01'


# cursor = ctx.cursor()
# fd = open('Queries/evaluacion.sql', 'r')
# sqlFile = fd.read()
# fd.close()
# cursor.execute(sqlFile.format(fecha_inicio=fecha_inicio,fecha_final=fecha_final))
# df = cursor.fetch_pandas_all()
# df = arreglo_caracteristicas(df)
# df.to_csv(f'APP_{fecha_final}.csv',index=False)
